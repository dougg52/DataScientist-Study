# %% [markdown]
# A abordagem de DataScience passa sobre o entendimento da modelagem estatistica. Assim um bom conhecimento dos algoritimos de modelagem é essêncial a um Cientista de dados:
#
# Modelos preditivos:
# Regressão Linear [x]
# Regularização L1 e L2 [X]
# Árvore de Regressão
# Análise de Residuo
#
# Modelos de classificação
# Regressão Logistica
# Naive Bayes
# KNN
# Árvore de Classificação
#
# Boost:
# Random Forest
# Estratégias de Boosting
# Redes Neurais
# SVM
#
# Clusterização
# K-Means/  K-medoids
# DBSCan
# Algoritimos Hierarquicos
# Estratégias de definição de nº de cluster
# GMM
#
# Redes Neurais
#
# ----
#
# Metricas de Performance:
# https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter
# Matriz de confusão
# Accuracy, Predict, F1 e F2
# ROC e AUC
# Correlação R² e ANOVA
# Cross-validation [ ]
# GrideSearch-CV [ ]
#
# -----
#
# ### Algoritimos, técnicas paralelas a modelagem; <br>
# Você precisa entender as ferramentas para otimizar, avaliar seus modelos
# https://towardsdatascience.com/what-makes-lightgbm-lightning-fast-a27cf0d9785e
# GridSearch
#
# ----
# ### Vocabulario de Negócio:
# Churn
#
# Modelagem de crédito:
# Inferência dos rejeitados
#
# Fraude:
# Open to buy
#
# ---
# Vocabulário:
# Aprendizado de máquina;
# Aprendizado supervisionado e não supervisionado;
# Não parametrico;
# cross validation;
# estimators;
# Hyper-parameters;
